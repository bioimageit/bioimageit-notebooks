# %% [markdown]
# # BioImageIT: deconvolution tutorial
#
# In this tutorial, we run deconvolution on a dataset. This tutorial has been created to show how to run this simple workflow either locally or with OMERO

# %% [markdown]
# ## 1- import the BioImageIT API

# %%
import bioimageit_core.api as iit

# initialize the BioImageIT request
req = iit.Request('../config.json')
req.connect()
# Out:
# Omero connect

# %% [markdown]
# ## 2- Create a new experiment and import raw data

# %%
print("Create experiment...")
experiment = req.create_experiment(name='tuto_deconvolution')
print("experiment created")
print("import data...")
req.import_dir(experiment=experiment,
               dir_uri='./synthetic_data/data/',
               filter_=r'\.tif$',
               format_='imagetiff')
print("data imported")
print("annotate data...")
req.annotate_from_name(experiment, "Population", ['population1', 'population2'] )
req.annotate_using_separator(experiment, key="number", separator="_", value_position=1) 
print("data annotated")

req.display_experiment(experiment)
# Out:
# Create experiment...
# experiment created
# import data...
# data imported
# annotate data...
# data annotated
# --------------------
# Experiment:
# 	Name:  tuto_deconvolution
# 	Author:  {'name': 'sprigent'}
# 	Created:  2022-03-28
# 	Key-value pairs:
# 		- Population
# 		- number
# 	DataSet:  data
# +---------------------+-------------+--------+----------------+--------------+
# |         Name        |  Population | number |     Author     | Created date |
# +---------------------+-------------+--------+----------------+--------------+
# | population1_001.tif | population1 |  001   | SylvainPrigent |  2022-03-28  |
# | population1_002.tif | population1 |  002   | SylvainPrigent |  2022-03-28  |
# | population1_003.tif | population1 |  003   | SylvainPrigent |  2022-03-28  |
# | population1_004.tif | population1 |  004   | SylvainPrigent |  2022-03-28  |
# | population1_005.tif | population1 |  005   | SylvainPrigent |  2022-03-28  |
# | population1_006.tif | population1 |  006   | SylvainPrigent |  2022-03-28  |
# | population1_007.tif | population1 |  007   | SylvainPrigent |  2022-03-28  |
# | population1_008.tif | population1 |  008   | SylvainPrigent |  2022-03-28  |
# | population1_009.tif | population1 |  009   | SylvainPrigent |  2022-03-28  |
# | population1_010.tif | population1 |  010   | SylvainPrigent |  2022-03-28  |
# | population1_011.tif | population1 |  011   | SylvainPrigent |  2022-03-28  |
# | population1_012.tif | population1 |  012   | SylvainPrigent |  2022-03-28  |
# | population1_013.tif | population1 |  013   | SylvainPrigent |  2022-03-28  |
# | population1_014.tif | population1 |  014   | SylvainPrigent |  2022-03-28  |
# | population1_015.tif | population1 |  015   | SylvainPrigent |  2022-03-28  |
# | population1_016.tif | population1 |  016   | SylvainPrigent |  2022-03-28  |
# | population1_017.tif | population1 |  017   | SylvainPrigent |  2022-03-28  |
# | population1_018.tif | population1 |  018   | SylvainPrigent |  2022-03-28  |
# | population1_019.tif | population1 |  019   | SylvainPrigent |  2022-03-28  |
# | population1_020.tif | population1 |  020   | SylvainPrigent |  2022-03-28  |
# | population2_001.tif | population2 |  001   | SylvainPrigent |  2022-03-28  |
# | population2_002.tif | population2 |  002   | SylvainPrigent |  2022-03-28  |
# | population2_003.tif | population2 |  003   | SylvainPrigent |  2022-03-28  |
# | population2_004.tif | population2 |  004   | SylvainPrigent |  2022-03-28  |
# | population2_005.tif | population2 |  005   | SylvainPrigent |  2022-03-28  |
# | population2_006.tif | population2 |  006   | SylvainPrigent |  2022-03-28  |
# | population2_007.tif | population2 |  007   | SylvainPrigent |  2022-03-28  |
# | population2_008.tif | population2 |  008   | SylvainPrigent |  2022-03-28  |
# | population2_009.tif | population2 |  009   | SylvainPrigent |  2022-03-28  |
# | population2_010.tif | population2 |  010   | SylvainPrigent |  2022-03-28  |
# | population2_011.tif | population2 |  011   | SylvainPrigent |  2022-03-28  |
# | population2_012.tif | population2 |  012   | SylvainPrigent |  2022-03-28  |
# | population2_013.tif | population2 |  013   | SylvainPrigent |  2022-03-28  |
# | population2_014.tif | population2 |  014   | SylvainPrigent |  2022-03-28  |
# | population2_015.tif | population2 |  015   | SylvainPrigent |  2022-03-28  |
# | population2_016.tif | population2 |  016   | SylvainPrigent |  2022-03-28  |
# | population2_017.tif | population2 |  017   | SylvainPrigent |  2022-03-28  |
# | population2_018.tif | population2 |  018   | SylvainPrigent |  2022-03-28  |
# | population2_019.tif | population2 |  019   | SylvainPrigent |  2022-03-28  |
# | population2_020.tif | population2 |  020   | SylvainPrigent |  2022-03-28  |
# +---------------------+-------------+--------+----------------+--------------+

# %% [markdown]
# ## 3- Run deconvolution

# %%
from bioimageit_core.containers import Job

# create the job
job = Job()
# set the experiment
job.set_experiment(experiment)
# set the tool
job.set_tool(req.get_tool('spitfiredeconv2d_v0.1.2'))
# query all the raw data for the spitfire input called 'i'
job.set_input(name='i', dataset='data', query='')
# set each parameters
job.set_param('sigma', '4')
job.set_param('regularization', '12')
job.set_param('weighting', '0.1')
job.set_param('method', 'SV')
job.set_param('padding', 'True')
# choose a name for the output dataset
job.set_output_dataset_name('deconv')

experiment = req.run(job)
# Out:
# get tool: spitfiredeconv2d_v0.1.2
#   Start job1
# job 1:  simglib env already exists
# job 1:  Process population1_001.tif, progress: 0
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_001.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_001.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_001.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_001.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 144 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_002.tif, progress: 2
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_002.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_002.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_002.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_002.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 147 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_003.tif, progress: 5
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_003.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_003.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_003.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_003.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 145 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_004.tif, progress: 7
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_004.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_004.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_004.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_004.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 146 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_005.tif, progress: 10
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_005.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_005.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_005.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_005.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 166 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_006.tif, progress: 12
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_006.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_006.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_006.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_006.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 147 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_007.tif, progress: 15
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_007.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_007.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_007.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_007.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 152 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_008.tif, progress: 17
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_008.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_008.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_008.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_008.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 156 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_009.tif, progress: 20
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_009.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_009.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_009.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_009.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 141 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_010.tif, progress: 22
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_010.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_010.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_010.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_010.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 148 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_011.tif, progress: 25
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_011.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_011.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_011.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_011.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 144 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_012.tif, progress: 27
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_012.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_012.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_012.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_012.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 146 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_013.tif, progress: 30
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_013.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_013.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_013.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_013.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 139 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_014.tif, progress: 32
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_014.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_014.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_014.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_014.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 143 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_015.tif, progress: 35
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_015.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_015.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_015.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_015.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 165 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_016.tif, progress: 37
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_016.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_016.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_016.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_016.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 144 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_017.tif, progress: 40
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_017.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_017.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_017.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_017.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 144 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_018.tif, progress: 42
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_018.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_018.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_018.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_018.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 146 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_019.tif, progress: 45
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_019.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_019.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_019.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_019.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 149 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population1_020.tif, progress: 47
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population1_020.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population1_020.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population1_020.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population1_020.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 150 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_001.tif, progress: 50
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_001.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_001.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_001.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_001.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 143 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_002.tif, progress: 52
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_002.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_002.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_002.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_002.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 144 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_003.tif, progress: 55
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_003.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_003.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_003.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_003.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 147 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_004.tif, progress: 57
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_004.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_004.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_004.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_004.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 149 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_005.tif, progress: 60
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_005.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_005.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_005.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_005.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# ...
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 147 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_013.tif, progress: 80
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_013.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_013.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_013.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_013.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 153 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_014.tif, progress: 82
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_014.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_014.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_014.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_014.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 149 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_015.tif, progress: 85
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_015.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_015.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_015.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_015.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 147 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_016.tif, progress: 87
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_016.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_016.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_016.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_016.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 143 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_017.tif, progress: 90
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_017.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_017.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_017.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_017.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 143 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_018.tif, progress: 92
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_018.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_018.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_018.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_018.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 143 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_019.tif, progress: 95
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_019.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_019.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_019.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_019.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 142 ms
# job 1:  save float image 128, 128, 1
# job 1:  Process population2_020.tif, progress: 97
# job 1:  Conda exec cmd: . "/Users/sprigent/BioimageIT/miniconda3/etc/profile.d/conda.sh" && conda activate simglib && "simgspitfiredeconv2d" "-i" "/Users/sprigent/Documents/bioimageit/workspace/population2_020.tif.tif" "-o" "/Users/sprigent/Documents/bioimageit/workspace/o_population2_020.tif" "-sigma" "4" "-regularization" "12" "-weighting" "0.1" "-method" "SV" "-padding" "True" "-niter" "200"
# job 1:  spitfire2d: input image: /Users/sprigent/Documents/bioimageit/workspace/population2_020.tif.tif
# job 1:  spitfire2d: output image: /Users/sprigent/Documents/bioimageit/workspace/o_population2_020.tif
# job 1:  spitfire2d: method: SV
# job 1:  spitfire2d: regularization parameter: 12.000000
# job 1:  spitfire2d: weighting parameter: 0.100000
# job 1:  spitfire2d: nb iterations: 200
# job 1:  spitfire2d: use padding
# job 1:  Use 8 threads
# job 1:                                                                        | 0 %
# job 1:                                                                        | 10 %
# job 1:                                                                        | 20 %
# job 1:                                                                        | 30 %
# job 1:                                                                        | 40 %
# job 1:                                                                        | 50 %
# job 1:                                                                        | 60 %
# job 1:                                                                        | 70 %
# job 1:                                                                        | 80 %
# job 1:                                                                        | 90 %
# job 1:                                                                        | 100 %
# job 1:  Elapsed time: 0 seconds 147 ms
# job 1:  save float image 128, 128, 1
# job 1:  done, progress: 100
#   Finished job1
